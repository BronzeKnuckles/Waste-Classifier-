# %% [raw]
# IMPORTING PACKAGES

# %%
from fastai.vision import *
from fastai.metrics import error_rate
from pathlib import Path

from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import os


import re

# %% [raw]
# /data
#      /train
#          /cardboard
#          /glass
#          /metal
#          /paper
#          /plastic
#          /trash
#      /valid
#          /cardboard
#          /glass
#          /metal
#          /paper
#          /plastic
#          /trash
#     /test
#
# Each image file is just the material name and a number (i.e. cardboard1.jpg)

# %%
# get path of the folder to extract for Batching
path = Path(os.getcwd())/"data"
path
# Out:
# PosixPath('/home/ot420/dm/Waste-Sorter/data')

# %%
tfms = get_transforms(do_flip=True,flip_vert=True)
data = ImageDataBunch.from_folder(path,test="test",ds_tfms=tfms,bs=16)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (1262 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /home/ot420/dm/Waste-Sorter/data;
#
# Valid: LabelList (630 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: CategoryList
# paper,paper,paper,paper,paper
# Path: /home/ot420/dm/Waste-Sorter/data;
#
# Test: LabelList (635 items)
# x: ImageList
# Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512),Image (3, 384, 512)
# y: EmptyLabelList
# ,,,,
# Path: /home/ot420/dm/Waste-Sorter/data

# %%
print(data.classes)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
data.show_batch(rows=4,figsize=(10,8))

# %% [raw]
# MODEL TRAINING

# %%
learn = cnn_learner(data,models.resnet34,metrics=error_rate)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=6, bias=True)
#   )
# )

# %%
learn.lr_find(start_lr=1e-6,end_lr=1e1)
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 9.55E-06
# Min loss divided by 10: 1.82E-06

# %% [raw]
# TRAINING

# %%
learn.fit_one_cycle(20,max_lr=3.55e-03)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.661911</td>
#       <td>0.458623</td>
#       <td>0.136508</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.572957</td>
#       <td>0.378664</td>
#       <td>0.117460</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.500864</td>
#       <td>0.347201</td>
#       <td>0.109524</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.525793</td>
#       <td>0.543033</td>
#       <td>0.138095</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.597000</td>
#       <td>0.467073</td>
#       <td>0.147619</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.608486</td>
#       <td>0.634351</td>
#       <td>0.198413</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.565965</td>
#       <td>0.465322</td>
#       <td>0.149206</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.560204</td>
#       <td>0.494214</td>
#       <td>0.147619</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.483950</td>
#       <td>0.356458</td>
#       <td>0.119048</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.437306</td>
#       <td>0.403992</td>
#       <td>0.139683</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.382333</td>
#       <td>0.262579</td>
#       <td>0.096825</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.329581</td>
#       <td>0.280672</td>
#       <td>0.085714</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.322700</td>
#       <td>0.238238</td>
#       <td>0.079365</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.314268</td>
#       <td>0.293020</td>
#       <td>0.087302</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.275572</td>
#       <td>0.232668</td>
#       <td>0.074603</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.215328</td>
#       <td>0.211724</td>
#       <td>0.074603</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.202828</td>
#       <td>0.206334</td>
#       <td>0.052381</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.178547</td>
#       <td>0.206299</td>
#       <td>0.061905</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.153216</td>
#       <td>0.203608</td>
#       <td>0.058730</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.135409</td>
#       <td>0.193190</td>
#       <td>0.050794</td>
#       <td>00:49</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# Make predictions on the test data using the learner.get_preds() method.
#
# -->learner.predict() only predicts on a single image, while learner.get_preds() predicts on a set of images.

# %%
preds = learn.get_preds(ds_type=DatasetType.Test)

# %% [markdown]
# Don't pass in data,pass in the dataset type. passing data gives an error.

# %%
print(preds[0].shape)
preds[0]
# Out:
# torch.Size([635, 6])
# tensor([[7.3493e-06, 9.9889e-01, 2.0506e-05, 1.2842e-04, 9.3983e-04, 9.7571e-06],
#         [2.7545e-06, 4.2325e-04, 4.6740e-05, 6.0230e-08, 9.9952e-01, 4.6275e-06],
#         [6.2960e-05, 9.5821e-03, 7.4339e-02, 8.0318e-06, 9.1578e-01, 2.2730e-04],
#         ...,
#         [1.0917e-08, 1.6713e-01, 1.4606e-04, 2.8577e-07, 8.3272e-01, 7.3896e-06],
#         [6.5371e-08, 7.0694e-08, 5.6775e-08, 9.9980e-01, 1.9233e-04, 2.8140e-06],
#         [1.1132e-08, 9.9914e-01, 1.3732e-04, 3.4506e-07, 7.1899e-04, 6.0781e-06]])

# %% [markdown]
# These are the predicted probablities for each image. This tensor has 365 rows,one for each image and 6 column,one for each material category.

# %%
data.classes
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# convert probabilites to their corresponding class

# %%
max_idxs = np.asarray(np.argmax(preds[0],axis=1))

# %%
ypred = []
for max_idx in max_idxs:
    ypred.append(data.classes[max_idx])

# %%
ypred
# Out:
# ['glass',
#  'plastic',
#  'plastic',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'cardboard',
#  'trash',
#  'plastic',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'trash',
#  'metal',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'metal',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'metal',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'trash',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'glass',
#  'trash',
#  'paper',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'trash',
#  'plastic',
#  'plastic',
#  'plastic',
#  'trash',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'trash',
#  'glass',
#  'cardboard',
#  'plastic',
#  'metal',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'cardboard',
#  'glass',
#  'metal',
#  'metal',
#  'metal',
#  'cardboard',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'trash',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'metal',
#  'glass',
#  'paper',
#  'trash',
#  'cardboard',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'metal',
#  'cardboard',
#  'trash',
#  'metal',
#  'trash',
#  'plastic',
#  'paper',
#  'glass',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'trash',
#  'cardboard',
#  'trash',
#  'plastic',
#  'glass',
#  'plastic',
#  'plastic',
#  'paper',
#  'trash',
#  'plastic',
#  'metal',
#  'glass',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'plastic',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'glass',
#  'metal',
#  'trash',
#  'metal',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'trash',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'metal',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'trash',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'trash',
#  'paper',
#  'paper',
#  'trash',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'metal',
#  'plastic',
#  'metal',
#  'trash',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'metal',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'trash',
#  'plastic',
#  'plastic',
#  'metal',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'trash',
#  'plastic',
#  'metal',
#  'metal',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'trash',
#  'glass',
#  'cardboard',
#  'metal',
#  'plastic',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'trash',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'trash',
#  'trash',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'trash',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'metal',
#  'glass',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'trash',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'glass',
#  'trash',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'plastic',
#  'trash',
#  'metal',
#  'trash',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'metal',
#  'cardboard',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'glass',
#  'metal',
#  'glass',
#  'metal',
#  'trash',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'glass',
#  'glass',
#  'metal',
#  'cardboard',
#  'metal',
#  'plastic',
#  'paper',
#  'trash',
#  'metal',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'glass']

# %% [markdown]
# These are the predicted labels of all the images.

# %%
learn.data.test_ds[0][0]
#picture of first img
# Out:
# Image (3, 384, 512)

# %%
y = []

#convert file paths to string 
for label_path in data.test_ds.items:
    y.append(str(label_path))

#extract waste type from file path
pattern = re.compile("([a-z]+)[0-9]+")
for i in range(len(y)):
    s = y[i]
    s = s[len(s)//2:]
    y[i] = s
    y[i] = pattern.search(y[i]).group(1)
# Out:
# ['glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'plastic',
#  'metal',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'trash',
#  'metal',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'trash',
#  'glass',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'cardboard',
#  'plastic',
#  'cardboard',
#  'glass',
#  'plastic',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'trash',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'trash',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'trash',
#  'glass',
#  'trash',
#  'paper',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'plastic',
#  'trash',
#  'plastic',
#  'plastic',
#  'glass',
#  'trash',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'trash',
#  'glass',
#  'cardboard',
#  'plastic',
#  'metal',
#  'metal',
#  'metal',
#  'glass',
#  'metal',
#  'cardboard',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'glass',
#  'plastic',
#  'metal',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'glass',
#  'trash',
#  'metal',
#  'paper',
#  'trash',
#  'glass',
#  'plastic',
#  'glass',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'metal',
#  'glass',
#  'paper',
#  'trash',
#  'cardboard',
#  'glass',
#  'metal',
#  'glass',
#  'metal',
#  'metal',
#  'paper',
#  'plastic',
#  'metal',
#  'cardboard',
#  'metal',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'glass',
#  'metal',
#  'glass',
#  'glass',
#  'plastic',
#  'cardboard',
#  'trash',
#  'trash',
#  'cardboard',
#  'trash',
#  'plastic',
#  'glass',
#  'plastic',
#  'plastic',
#  'paper',
#  'trash',
#  'plastic',
#  'metal',
#  'glass',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'plastic',
#  'paper',
#  'cardboard',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'trash',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'metal',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'trash',
#  'paper',
#  'glass',
#  'metal',
#  'trash',
#  'glass',
#  'metal',
#  'metal',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'plastic',
#  'metal',
#  'paper',
#  'paper',
#  'metal',
#  'paper',
#  'cardboard',
#  'paper',
#  'plastic',
#  'plastic',
#  'trash',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'glass',
#  'glass',
#  'paper',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'trash',
#  'paper',
#  'cardboard',
#  'trash',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'metal',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'plastic',
#  'metal',
#  'plastic',
#  'metal',
#  'trash',
#  'glass',
#  'plastic',
#  'plastic',
#  'plastic',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'glass',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'trash',
#  'plastic',
#  'plastic',
#  'metal',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'metal',
#  'plastic',
#  'metal',
#  'metal',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'glass',
#  'glass',
#  'cardboard',
#  'glass',
#  'paper',
#  'metal',
#  'metal',
#  'metal',
#  'paper',
#  'trash',
#  'plastic',
#  'plastic',
#  'metal',
#  'cardboard',
#  'glass',
#  'trash',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'plastic',
#  'paper',
#  'metal',
#  'paper',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'paper',
#  'cardboard',
#  'glass',
#  'metal',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'paper',
#  'paper',
#  'trash',
#  'glass',
#  'cardboard',
#  'metal',
#  'plastic',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'glass',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'metal',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'plastic',
#  'paper',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'trash',
#  'cardboard',
#  'cardboard',
#  'plastic',
#  'trash',
#  'trash',
#  'cardboard',
#  'glass',
#  'paper',
#  'paper',
#  'cardboard',
#  'plastic',
#  'glass',
#  'metal',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'metal',
#  'glass',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'plastic',
#  'plastic',
#  'plastic',
#  'paper',
#  'metal',
#  'cardboard',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'glass',
#  'glass',
#  'paper',
#  'plastic',
#  'plastic',
#  'plastic',
#  'cardboard',
#  'metal',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'plastic',
#  'paper',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'glass',
#  'cardboard',
#  'plastic',
#  'paper',
#  'paper',
#  'glass',
#  'glass',
#  'glass',
#  'cardboard',
#  'plastic',
#  'glass',
#  'paper',
#  'plastic',
#  'cardboard',
#  'cardboard',
#  'paper',
#  'glass',
#  'trash',
#  'paper',
#  'glass',
#  'paper',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'plastic',
#  'metal',
#  'metal',
#  'glass',
#  'paper',
#  'paper',
#  'glass',
#  'cardboard',
#  'paper',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'glass',
#  'plastic',
#  'cardboard',
#  'glass',
#  'plastic',
#  'glass',
#  'paper',
#  'paper',
#  'paper',
#  'plastic',
#  'cardboard',
#  'paper',
#  'paper',
#  'metal',
#  'metal',
#  'paper',
#  'glass',
#  'plastic',
#  'paper',
#  'glass',
#  'plastic',
#  'glass',
#  'glass',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'plastic',
#  'trash',
#  'metal',
#  'trash',
#  'metal',
#  'plastic',
#  'glass',
#  'glass',
#  'plastic',
#  'plastic',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'paper',
#  'cardboard',
#  'metal',
#  'cardboard',
#  'paper',
#  'metal',
#  'cardboard',
#  'paper',
#  'plastic',
#  'cardboard',
#  'metal',
#  'glass',
#  'paper',
#  'glass',
#  'metal',
#  'trash',
#  'plastic',
#  'metal',
#  'paper',
#  'plastic',
#  'glass',
#  'cardboard',
#  'cardboard',
#  'metal',
#  'glass',
#  'glass',
#  'metal',
#  'cardboard',
#  'metal',
#  'plastic',
#  'paper',
#  'cardboard',
#  'metal',
#  'glass',
#  'metal',
#  'metal',
#  'plastic',
#  'cardboard',
#  'plastic',
#  'plastic',
#  'paper',
#  'glass']

# %%
cm = confusion_matrix(y,ypred)
correct = 0

for r in range(len(cm)):
    for c in range(len(cm)):
        if (r==c):
            correct += cm[r,c]


accuracy = correct/sum(sum(cm))
print("The accuracy of the model is:",accuracy*100)
# Out:
# The accuracy of the model is: 92.28346456692913

# %%
print("Actual: ",y[50:60])
print("Predicted: ",ypred[50:60])
# Out:
# Actual:  ['paper', 'glass', 'cardboard', 'metal', 'cardboard', 'paper', 'plastic', 'plastic', 'paper', 'cardboard']
# Predicted:  ['paper', 'glass', 'cardboard', 'metal', 'cardboard', 'paper', 'plastic', 'plastic', 'paper', 'cardboard']
